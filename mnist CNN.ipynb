# %%
# Import Libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import (
    Conv2D,
    MaxPooling2D,
    Flatten,
    Dense,
    Dropout,
    BatchNormalization,
    GlobalAveragePooling2D,
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from collections import Counter

# Load Dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Inspect Data
print(f"Training samples: {x_train.shape[0]}")
print(f"Test samples: {x_test.shape[0]}")
print(f"Image shape: {x_train.shape[1:]}")  # (28, 28)

# Visualize Sample Images
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(f"Label: {y_train[i]}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# Normalize Data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape Data
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)
print(f"New training shape: {x_train.shape}")
print(f"New test shape: {x_test.shape}")

# One-Hot Encode Labels
num_classes = 10
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
print(f"One-hot encoded y_train shape: {y_train.shape}")
print(f"One-hot encoded y_test shape: {y_test.shape}")

# Exploratory Data Analysis
plt.figure(figsize=(8, 6))
sns.countplot(np.argmax(y_train, axis=1))
plt.title('Distribution of Digits in Training Set')
plt.xlabel('Digit')
plt.ylabel('Frequency')
plt.show()

counter = Counter(np.argmax(y_train, axis=1))
print("Training set class distribution:", counter)

# Define CNN Model
def create_cnn_model(input_shape=(28, 28, 1), num_classes=10):
    model = Sequential()

    # First Convolutional Block
    model.add(
        Conv2D(
            32,
            (3, 3),
            activation='relu',
            input_shape=input_shape,
            padding='same',
            kernel_initializer='he_normal',
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))

    # Second Convolutional Block
    model.add(
        Conv2D(
            64,
            (3, 3),
            activation='relu',
            padding='same',
            kernel_initializer='he_normal',
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))

    # Third Convolutional Block
    model.add(
        Conv2D(
            128,
            (3, 3),
            activation='relu',
            padding='same',
            kernel_initializer='he_normal',
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))

    # Flatten and Dense Layers
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_normal'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))

    return model

# Instantiate and Compile Model
model = create_cnn_model()
model.summary()

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
)
datagen.fit(x_train)

# Define Callbacks
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1,
)
checkpoint = ModelCheckpoint(
    'best_cnn_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1,
)

# Train the Model
batch_size = 64
epochs = 30

history = model.fit(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    steps_per_epoch=x_train.shape[0] // batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[early_stop, checkpoint],
)

# Load the Best Model
best_model = load_model('best_cnn_model.keras')

# Evaluate on Test Data
test_loss, test_accuracy = best_model.evaluate(x_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Test Loss: {test_loss:.4f}")

# Classification Report and Confusion Matrix
y_pred = best_model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

print("Classification Report:")
print(classification_report(y_true, y_pred_classes))

conf_mat = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(
    conf_mat,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=range(10),
    yticklabels=range(10),
)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Save the Model
best_model.save('final_cnn_model.keras')
print("Model saved to disk.")

# Load the Model (if needed)
#loaded_model = load_model('final_cnn_model.keras')
#print("Model loaded from disk.")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training samples: 60000
# Test samples: 10000
# Image shape: (28, 28)
# New training shape: (60000, 28, 28, 1)
# New test shape: (10000, 28, 28, 1)
# One-hot encoded y_train shape: (60000, 10)
# One-hot encoded y_test shape: (10000, 10)
# Training set class distribution: Counter({1: 6742, 7: 6265, 3: 6131, 2: 5958, 9: 5949, 0: 5923, 6: 5918, 8: 5851, 4: 5842, 5: 5421})
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 28, 28, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 14, 14, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 7, 7, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 7, 7, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 3, 3, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 3, 3, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1152)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 242,954 (949.04 KB)
#  Trainable params: 242,250 (946.29 KB)
#  Non-trainable params: 704 (2.75 KB)
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 931/937 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7304 - loss: 0.8645
# Epoch 1: val_accuracy improved from -inf to 0.98340, saving model to best_cnn_model.keras
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 41s 33ms/step - accuracy: 0.7313 - loss: 0.8615 - val_accuracy: 0.9834 - val_loss: 0.0463
# Epoch 2/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9688 - loss: 0.0817
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 2: val_accuracy did not improve from 0.98340
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 700us/step - accuracy: 0.9688 - loss: 0.0817 - val_accuracy: 0.9833 - val_loss: 0.0464
# Epoch 3/30
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9489 - loss: 0.1645
# Epoch 3: val_accuracy improved from 0.98340 to 0.98900, saving model to best_cnn_model.keras
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 25s 26ms/step - accuracy: 0.9489 - loss: 0.1645 - val_accuracy: 0.9890 - val_loss: 0.0316
# Epoch 4/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9531 - loss: 0.1687
# Epoch 4: val_accuracy did not improve from 0.98900
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 584us/step - accuracy: 0.9531 - loss: 0.1687 - val_accuracy: 0.9890 - val_loss: 0.0314
# Epoch 5/30
# 932/937 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9611 - loss: 0.1220
# Epoch 5: val_accuracy did not improve from 0.98900
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 25s 26ms/step - accuracy: 0.9611 - loss: 0.1220 - val_accuracy: 0.9879 - val_loss: 0.0330
# Epoch 6/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9531 - loss: 0.1019
# Epoch 6: val_accuracy did not improve from 0.98900
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 692us/step - accuracy: 0.9531 - loss: 0.1019 - val_accuracy: 0.9879 - val_loss: 0.0331
# Epoch 7/30
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9678 - loss: 0.1039
# Epoch 7: val_accuracy improved from 0.98900 to 0.99090, saving model to best_cnn_model.keras
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 40s 26ms/step - accuracy: 0.9678 - loss: 0.1039 - val_accuracy: 0.9909 - val_loss: 0.0257
# Epoch 8/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9688 - loss: 0.0970
# Epoch 8: val_accuracy did not improve from 0.99090
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 598us/step - accuracy: 0.9688 - loss: 0.0970 - val_accuracy: 0.9908 - val_loss: 0.0257
# Epoch 9/30
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9720 - loss: 0.0927
# Epoch 9: val_accuracy improved from 0.99090 to 0.99210, saving model to best_cnn_model.keras
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 24s 26ms/step - accuracy: 0.9720 - loss: 0.0927 - val_accuracy: 0.9921 - val_loss: 0.0225
# Epoch 10/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 10: val_accuracy did not improve from 0.99210
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 591us/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.9921 - val_loss: 0.0228
# Epoch 11/30
# 935/937 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9776 - loss: 0.0745
# Epoch 11: val_accuracy improved from 0.99210 to 0.99260, saving model to best_cnn_model.keras
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 39s 25ms/step - accuracy: 0.9776 - loss: 0.0745 - val_accuracy: 0.9926 - val_loss: 0.0191
# Epoch 12/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9531 - loss: 0.1516
# Epoch 12: val_accuracy improved from 0.99260 to 0.99270, saving model to best_cnn_model.keras
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 893us/step - accuracy: 0.9531 - loss: 0.1516 - val_accuracy: 0.9927 - val_loss: 0.0191
# Epoch 13/30
# 931/937 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9770 - loss: 0.0739
# Epoch 13: val_accuracy improved from 0.99270 to 0.99430, saving model to best_cnn_model.keras
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 24s 25ms/step - accuracy: 0.9770 - loss: 0.0739 - val_accuracy: 0.9943 - val_loss: 0.0170
# Epoch 14/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 14: val_accuracy improved from 0.99430 to 0.99450, saving model to best_cnn_model.keras
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 762us/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9945 - val_loss: 0.0171
# Epoch 15/30
# 931/937 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9792 - loss: 0.0696
# Epoch 15: val_accuracy did not improve from 0.99450
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.9792 - loss: 0.0696 - val_accuracy: 0.9932 - val_loss: 0.0198
# Epoch 16/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9688 - loss: 0.1533
# Epoch 16: val_accuracy did not improve from 0.99450
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 695us/step - accuracy: 0.9688 - loss: 0.1533 - val_accuracy: 0.9931 - val_loss: 0.0197
# Epoch 17/30
# 935/937 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9810 - loss: 0.0649
# Epoch 17: val_accuracy did not improve from 0.99450
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 24s 25ms/step - accuracy: 0.9810 - loss: 0.0649 - val_accuracy: 0.9943 - val_loss: 0.0167
# Epoch 18/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9688 - loss: 0.0853
# Epoch 18: val_accuracy did not improve from 0.99450
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 608us/step - accuracy: 0.9688 - loss: 0.0853 - val_accuracy: 0.9942 - val_loss: 0.0167
# Epoch 19/30
# 931/937 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9810 - loss: 0.0626
# Epoch 19: val_accuracy did not improve from 0.99450
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.9810 - loss: 0.0626 - val_accuracy: 0.9929 - val_loss: 0.0196
# Epoch 20/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9375 - loss: 0.2027
# Epoch 20: val_accuracy did not improve from 0.99450
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 696us/step - accuracy: 0.9375 - loss: 0.2027 - val_accuracy: 0.9932 - val_loss: 0.0195
# Epoch 21/30
# 931/937 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9804 - loss: 0.0615
# Epoch 21: val_accuracy improved from 0.99450 to 0.99570, saving model to best_cnn_model.keras
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 24s 26ms/step - accuracy: 0.9804 - loss: 0.0615 - val_accuracy: 0.9957 - val_loss: 0.0140
# Epoch 22/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 1.0000 - loss: 0.0144
# Epoch 22: val_accuracy did not improve from 0.99570
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 695us/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.9957 - val_loss: 0.0140
# Epoch 23/30
# 931/937 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9837 - loss: 0.0561
# Epoch 23: val_accuracy did not improve from 0.99570
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 24s 25ms/step - accuracy: 0.9837 - loss: 0.0561 - val_accuracy: 0.9953 - val_loss: 0.0145
# Epoch 24/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9688 - loss: 0.1621
# Epoch 24: val_accuracy did not improve from 0.99570
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 560us/step - accuracy: 0.9688 - loss: 0.1621 - val_accuracy: 0.9954 - val_loss: 0.0145
# Epoch 25/30
# 933/937 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9842 - loss: 0.0504
# Epoch 25: val_accuracy did not improve from 0.99570
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 42s 27ms/step - accuracy: 0.9842 - loss: 0.0504 - val_accuracy: 0.9946 - val_loss: 0.0162
# Epoch 26/30
#   1/937 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9688 - loss: 0.0414
# Epoch 26: val_accuracy did not improve from 0.99570
# 937/937 ━━━━━━━━━━━━━━━━━━━━ 1s 694us/step - accuracy: 0.9688 - loss: 0.0414 - val_accuracy: 0.9946 - val_loss: 0.0162
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Test Accuracy: 99.57%
# Test Loss: 0.0140
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       980
#            1       1.00      0.99      1.00      1135
#            2       1.00      1.00      1.00      1032
#            3       1.00      1.00      1.00      1010
#            4       0.99      1.00      0.99       982
#            5       1.00      0.99      1.00       892
#            6       0.99      1.00      1.00       958
#            7       0.99      1.00      0.99      1028
#            8       1.00      0.99      1.00       974
#            9       1.00      0.99      0.99      1009
#
#     accuracy                           1.00     10000
#    macro avg       1.00      1.00      1.00     10000
# weighted avg       1.00      1.00      1.00     10000
# Model saved to disk.
